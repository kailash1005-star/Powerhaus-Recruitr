# %%
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed"],
    search_term="Python",
    location="chennai",
    results_wanted=10,
    hours_old=100
)
print(jobs)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
